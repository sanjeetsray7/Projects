# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Image Loading Methods

# %%
# Method 1: IPython

from IPython.display import Image
filename = "3.jpg"
Image(filename= filename, width= 224, height=224)

# %%
# Method 2:  tensorflow and keras

from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size=(224,224))
plt.imshow(img)

# %%
# Method 3: Opencv-Python

import cv2

imgg = cv2.imread(filename)
imgg = cv2.resize(imgg, (224,224))
plt.imshow(imgg)

plt.imshow(cv2.cvtColor(imgg, cv2.COLOR_BGR2RGB))

# %%
# Method 4: from PIL

from PIL import Image

# %%
im = Image.open(filename)
im = im.resize((224,224))
plt.imshow(im)

# %%
## loading the deep learning model
## mobilenet : a pre-trained deep learning architecture

mobile = tf.keras.applications.mobilenet.MobileNet()

# %%
## creating a model
## training a model
## test a model
## predicta a model

# %%
## pre-processing of image

from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size=(224,224))
plt.imshow(img)

# %%
resized_img = image.img_to_array(img)
resized_img.shape
# Out:
# (224, 224, 3)

# %%
final_img = np.expand_dims(resized_img, axis=0)
final_img = tf.keras.applications.mobilenet.preprocess_input(final_img)
final_img.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions = mobile.predict(final_img)

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
result = imagenet_utils.decode_predictions(predictions)
result
# Out:
# [[('n04285008', 'sports_car', 0.9677402),
#   ('n03100240', 'convertible', 0.009260062),
#   ('n02814533', 'beach_wagon', 0.005654924),
#   ('n04037443', 'racer', 0.004968352),
#   ('n03770679', 'minivan', 0.0036972752)]]

# %%
mobile = tf.keras.applications.mobilenet_v2.MobileNetV2()

# %%
predictions = mobile.predict(final_img)

from tensorflow.keras.applications import imagenet_utils

result = imagenet_utils.decode_predictions(predictions)
result
# Out:
# [[('n04285008', 'sports_car', 0.77429634),
#   ('n03100240', 'convertible', 0.1496892),
#   ('n04037443', 'racer', 0.005574635),
#   ('n02974003', 'car_wheel', 0.004969758),
#   ('n03670208', 'limousine', 0.004811203)]]
